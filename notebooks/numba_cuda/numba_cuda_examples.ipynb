# %%
# !nsys profile -s none --stats=true python3 icassp_scipy_v1.py float32 2
# Out:
# WARNING: Backtraces will not be collected because sampling is disabled.
# ...
# Traceback (most recent call last):
#   File "icassp_scipy_v1.py", line 17, in <module>
#     from cupy import prof
# ModuleNotFoundError: No module named 'cupy'
#
# The target application returned non-zero exit code 1
# Processing events...
# Saving temporary "/tmp/nsys-report-33c6-d814-8389-18a1.qdstrm" file to disk...
#
# Creating final output files...
# Processing [==============================================================100%]
# Saved report file to "/tmp/nsys-report-33c6-d814-8389-18a1.qdrep"
# Exporting 62717 events: [=================================================100%]
#
# Exported successfully to
# /tmp/nsys-report-33c6-d814-8389-18a1.sqlite
#
#
# Operating System Runtime API Statistics:
#
#  Time(%)  Total Time (ns)  Num Calls  Average   Minimum   Maximum         Name
#  -------  ---------------  ---------  --------  -------  ----------  --------------
# ...

# %%
# !python3 icassp_scipy_v1.py float32 2
# Out:
# Traceback (most recent call last):
#   File "icassp_scipy_v1.py", line 17, in <module>
#     from cupy import prof
# ModuleNotFoundError: No module named 'cupy'

# %%
conda list
# Out:
# # packages in environment at /home/belt/anaconda3/envs/cusignal_cupy8:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                      1_llvm    conda-forge
# acoustics                 0.2.4.post0              pypi_0    pypi
# alabaster                 0.7.12                     py_0    conda-forge
# alsa-lib                  1.2.3                h516909a_0    conda-forge
# appdirs                   1.4.4              pyh9f0ad1d_0    conda-forge
# attrs                     20.3.0             pyhd3deb0d_0    conda-forge
# babel                     2.9.0              pyhd3deb0d_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.0                        py_2    conda-forge
# backports.functools_lru_cache 1.6.4              pyhd8ed1ab_0    conda-forge
# ...
