# %%
# !nsys profile -s none --stats=true python3 icassp_scipy_v1.py float32 2
# Out:
# WARNING: Backtraces will not be collected because sampling is disabled.
# ...
# Processing events...
# Saving temporary "/tmp/nsys-report-e80b-e001-4309-3b6f.qdstrm" file to disk...
#
# Creating final output files...
# Processing [==============================================================100%]
# Saved report file to "/tmp/nsys-report-e80b-e001-4309-3b6f.qdrep"
# Exporting 2164 events: [==================================================100%]
#
# Exported successfully to
# /tmp/nsys-report-e80b-e001-4309-3b6f.sqlite
#
#
# Operating System Runtime API Statistics:
#
#  Time(%)  Total Time (ns)  Num Calls   Average   Minimum   Maximum      Name
#  -------  ---------------  ---------  ---------  -------  ----------  ---------
#     84.3       20,356,074        530   38,407.7    1,003  15,712,482  read
#      6.6        1,590,090        722    2,202.3    1,559       4,579  open64
#      3.7          882,972          1  882,972.0  882,972     882,972  fork
# ...

# %%
# !nsys profile -s none --stats=true python3 icassp_cupy_v1.py float32 2
# Out:
# WARNING: Backtraces will not be collected because sampling is disabled.
# ...
# Processing events...
# Saving temporary "/tmp/nsys-report-1282-cc69-efef-8619.qdstrm" file to disk...
#
# Creating final output files...
# Processing [==============================================================100%]
# Saved report file to "/tmp/nsys-report-1282-cc69-efef-8619.qdrep"
# Exporting 3618 events: [==================================================100%]
#
# Exported successfully to
# /tmp/nsys-report-1282-cc69-efef-8619.sqlite
#
#
# CUDA API Statistics:
#
#  Time(%)  Total Time (ns)  Num Calls    Average      Minimum      Maximum              Name
#  -------  ---------------  ---------  ------------  ----------  -----------  ------------------------
#     80.6      281,269,568          6  46,878,261.3       4,343  280,768,030  cudaMalloc
#     17.2       59,920,602          1  59,920,602.0  59,920,602   59,920,602  cuModuleLoadData
# ...

# %%
# !nsys profile -s none --stats=true python3 icassp_cupy_v2.py float32 2
# Out:
# WARNING: Backtraces will not be collected because sampling is disabled.
# ...
# Registers 34
# Processing events...
# Saving temporary "/tmp/nsys-report-a66a-f1d4-e4b3-cb3d.qdstrm" file to disk...
#
# Creating final output files...
# Processing [==============================================================100%]
# Saved report file to "/tmp/nsys-report-a66a-f1d4-e4b3-cb3d.qdrep"
# Exporting 3571 events: [==================================================100%]
#
# Exported successfully to
# /tmp/nsys-report-a66a-f1d4-e4b3-cb3d.sqlite
#
#
# CUDA API Statistics:
#
#  Time(%)  Total Time (ns)  Num Calls    Average      Minimum     Maximum              Name
#  -------  ---------------  ---------  ------------  ---------  -----------  ------------------------
#     96.5      316,812,709          6  52,802,118.2      8,750  316,326,585  cudaMalloc
#      2.2        7,076,876          3   2,358,958.7  1,664,387    2,736,393  cudaDeviceSynchronize
# ...

# %%
# !nsys profile -s none --stats=true python3 icassp_cupy_v3.py float32 2
# Out:
# WARNING: Backtraces will not be collected because sampling is disabled.
# ...
# Registers 32
# Processing events...
# Saving temporary "/tmp/nsys-report-0c45-f7a2-95db-0d86.qdstrm" file to disk...
#
# Creating final output files...
# Processing [==============================================================100%]
# Saved report file to "/tmp/nsys-report-0c45-f7a2-95db-0d86.qdrep"
# Exporting 3510 events: [==================================================100%]
#
# Exported successfully to
# /tmp/nsys-report-0c45-f7a2-95db-0d86.sqlite
#
#
# CUDA API Statistics:
#
#  Time(%)  Total Time (ns)  Num Calls    Average      Minimum      Maximum              Name
#  -------  ---------------  ---------  ------------  ----------  -----------  ------------------------
#     70.4      213,856,910          6  35,642,818.3       4,127  213,430,875  cudaMalloc
#     26.8       81,305,705          1  81,305,705.0  81,305,705   81,305,705  cuModuleLoadData
# ...

# %%
# !nsys profile -s none --stats=true python3 icassp_cupy_v4.py float32 2
# Out:
# WARNING: Backtraces will not be collected because sampling is disabled.
# ...
# Registers 31
# Processing events...
# Saving temporary "/tmp/nsys-report-af3c-beca-88e3-0777.qdstrm" file to disk...
#
# Creating final output files...
# Processing [==============================================================100%]
# Saved report file to "/tmp/nsys-report-af3c-beca-88e3-0777.qdrep"
# Exporting 3596 events: [==================================================100%]
#
# Exported successfully to
# /tmp/nsys-report-af3c-beca-88e3-0777.sqlite
#
#
# CUDA API Statistics:
#
#  Time(%)  Total Time (ns)  Num Calls    Average      Minimum      Maximum              Name
#  -------  ---------------  ---------  ------------  ----------  -----------  ------------------------
#     80.0      289,425,581          6  48,237,596.8       4,493  288,988,387  cudaMalloc
#     17.6       63,555,366          1  63,555,366.0  63,555,366   63,555,366  cuModuleLoadData
# ...

# %%
# !nvcc --fatbin -std=c++11 --use_fast_math \
	--generate-code arch=compute_35,code=sm_35 \
	--generate-code arch=compute_35,code=sm_37 \
	--generate-code arch=compute_50,code=sm_50 \
	--generate-code arch=compute_50,code=sm_52 \
	--generate-code arch=compute_53,code=sm_53 \
	--generate-code arch=compute_60,code=sm_60 \
	--generate-code arch=compute_61,code=sm_61 \
	--generate-code arch=compute_62,code=sm_62 \
	--generate-code arch=compute_70,code=sm_70 \
	--generate-code arch=compute_72,code=sm_72 \
	--generate-code arch=compute_75,code=[sm_75,compute_75] \
	_lombscargle.cu -odir .
# Out:
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).

# %%
# !nsys profile -s none --stats=true python3 icassp_cupy_v5.py float32 2
# Out:
# WARNING: Backtraces will not be collected because sampling is disabled.
# ...

# %%
# !nvcc --fatbin -std=c++11 --use_fast_math \
	--generate-code arch=compute_35,code=sm_35 \
	--generate-code arch=compute_35,code=sm_37 \
	--generate-code arch=compute_50,code=sm_50 \
	--generate-code arch=compute_50,code=sm_52 \
	--generate-code arch=compute_53,code=sm_53 \
	--generate-code arch=compute_60,code=sm_60 \
	--generate-code arch=compute_61,code=sm_61 \
	--generate-code arch=compute_62,code=sm_62 \
	--generate-code arch=compute_70,code=sm_70 \
	--generate-code arch=compute_72,code=sm_72 \
	--generate-code arch=compute_75,code=[sm_75,compute_75] \
	_lombscargle_lb.cu -odir .

# %%
# !nsys profile -s none --stats=true python3 icassp_cupy_v6.py float32 2
# Out:
# WARNING: Backtraces will not be collected because sampling is disabled.
# ...
# Traceback (most recent call last):
#   File "icassp_cupy_v6.py", line 134, in <module>
#     gpu_lombscargle = lombscargle(d_x, d_y, d_f)
#   File "icassp_cupy_v6.py", line 93, in lombscargle
#     _lombscargle(x, y_in, freqs, pgram, y_dot)
#   File "icassp_cupy_v6.py", line 40, in _lombscargle
#     kernel = _kernel_cache[(str(pgram.dtype))] = module.get_function("_cupy_lombscargle_" + str(pgram.dtype))
#   File "cupy/_core/raw.pyx", line 485, in cupy._core.raw.RawModule.get_function
#   File "cupy/_core/raw.pyx", line 96, in cupy._core.raw.RawKernel.kernel.__get__
#   File "cupy/_core/raw.pyx", line 113, in cupy._core.raw.RawKernel._kernel
#   File "cupy/_util.pyx", line 59, in cupy._util.memoize.decorator.ret
#   File "cupy/_core/raw.pyx", line 555, in cupy._core.raw._get_raw_module
#   File "cupy/cuda/function.pyx", line 239, in cupy.cuda.function.Module.load_file
# ...
